# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,11,10)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='blue')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='lightblue')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='purple')#RGB HFX Code

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#650dbd')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017')
ax.plot(x,x+1,color='purple')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',label='x v x')
ax.plot(x,x+1,color='purple',label='x vs x+1')
ax.legend()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',lw=1)
ax.plot(x,x+1,color='purple')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',lw=10)#lw-linewidth
ax.plot(x,x+1,color='purple')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',lw=10)#lw-linewidth
ax.plot(x,x+1,color='purple',linewidth=5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',lw=10)#lw-linewidth
ax.plot(x,x+1,color='purple',linewidth=0.5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',lw=10,ls='--')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=0.5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',lw=10,ls='--')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=2,linestyle='-.')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=2,linestyle='-.')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=5,linestyle='-.')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
lines=ax.plot(x,x+1,color='purple',linewidth=5)

# %%
type(lines)
# Out:
# list

# %%
lines

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
lines=ax.plot(x,x+1,color='purple',linewidth=5)
lines[0].set_dashes([1,1,1,2,3,5])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
lines=ax.plot(x,x+1,color='purple',linewidth=5)
lines[0].set_dashes([5,2,10,2])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
lines=ax.plot(x,x+1,color='purple',linewidth=5)
lines[0].set_dashes([3])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
lines=ax.plot(x,x+1,color='purple',linewidth=5)
lines[0].set_dashes([5,2,5,2])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
lines=ax.plot(x,x+1,color='purple',linewidth=5)
lines[0].set_dashes([1,2,1,2,10,2])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=5)

# %%
x
# Out:
# array([ 0.        ,  1.22222222,  2.44444444,  3.66666667,  4.88888889,
#         6.11111111,  7.33333333,  8.55555556,  9.77777778, 11.        ])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=5,marker='o')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=2,marker='o')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x+1,color='purple',linewidth=2,marker='o',ls='--')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='o',ls='--')
ax.plot(x,x+1,color='purple',linewidth=2,marker='+',ls='--')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='o',ls='--')
ax.plot(x,x+1,color='red',linewidth=2,marker='+',ls='--',markersize=20)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='o',ls='--',ms=10)#ms-markersize
ax.plot(x,x+1,color='red',linewidth=2,marker='+',ls='--',markersize=20)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='o',ls='--',ms=10,
       markerfacecolor='red',markeredgewidth=8,markeredgecolor='orange')#ms-markersize

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='o',ls='--',ms=10,
       markerfacecolor='red',markeredgewidth=20,markeredgecolor='orange')#ms-markersize

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='o',ls='--',ms=10,
       markerfacecolor='red',markeredgewidth=4,markeredgecolor='orange')#ms-markersize

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='s',ls='--',ms=10,
       markerfacecolor='red',markeredgewidth=4,markeredgecolor='orange')#ms-markersize

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
#ax.plot(x,x,color='#e6c017',lw=10,ls=':')#lw-linewidth,ls-linestyle
ax.plot(x,x,color='purple',linewidth=2,marker='s',ls='--',ms=15,
       markerfacecolor='red',markeredgewidth=4,markeredgecolor='orange')#ms-markersize
